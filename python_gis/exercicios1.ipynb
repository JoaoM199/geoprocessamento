# %% [markdown]
# # Exercícios de fixação

# %% [markdown]
# 1) Abrir o Arquivo municípios.shp

# %%
# Importando bibliotecas
import geopandas as gpd;
import matplotlib as plt;
import os;

# Importando shapefile
path = os.getcwd() + "/dados/municipios.shp"
data = gpd.read_file(path)
data
# Out:
#         id  id_pk geocodigo           municipio  uf        regiao  area  \
# 0        1      1   5100102            Acorizal  MT  Centro-Oeste   NaN
# 1        2    104   5107156  Reserva Do Cabaçal  MT  Centro-Oeste   NaN
# 2        3    144   5200100           Abadiânia  GO  Centro-Oeste   NaN
# 3        4    147   5200175  Água Fria De Goiás  GO  Centro-Oeste   NaN
# 4        5    160   5201306             Anicuns  GO  Centro-Oeste   NaN
# ...    ...    ...       ...                 ...  ..           ...   ...
# 6124  6125   6120   4128401                Uraí  PR           Sul   NaN
# 6125  6126   6121   4128500      Wenceslau Braz  PR           Sul   NaN
# 6126  6127   6123   4128559  Vera Cruz Do Oeste  PR           Sul   NaN
# 6127  6128   6125   4128625        Alto Paraíso  PR           Sul   NaN
# 6128  6129   6128   4128708            Vitorino  PR           Sul   NaN
#
#                                                geometry
# ...

# %% [markdown]
# 2) Visualize os 5 primeiros valores do arquivo

# %%
data[:5]
# Out:
#    id  id_pk geocodigo           municipio  uf        regiao  area  \
# 0   1      1   5100102            Acorizal  MT  Centro-Oeste   NaN
# 1   2    104   5107156  Reserva Do Cabaçal  MT  Centro-Oeste   NaN
# 2   3    144   5200100           Abadiânia  GO  Centro-Oeste   NaN
# 3   4    147   5200175  Água Fria De Goiás  GO  Centro-Oeste   NaN
# 4   5    160   5201306             Anicuns  GO  Centro-Oeste   NaN
#
#                                             geometry
# 0  POLYGON ((-56.28986 -15.23886, -56.28991 -15.2...
# 1  POLYGON ((-58.50758 -15.005, -58.72273 -15.004...
# 2  POLYGON ((-48.91412 -16.08702, -48.91283 -16.0...
# 3  POLYGON ((-47.8574 -14.76522, -47.85657 -14.76...
# 4  POLYGON ((-49.98332 -16.3266, -49.98259 -16.32...

# %% [markdown]
# 3) Plote os 5 primeiros valores do arquivo

# %%
primeiros = data[:5]
primeiros.plot()
# Out:
# <Axes: >

# %% [markdown]
# 4) Realize um filtro e salve um novo arquivo chamado municipios_MT

# %%
mask = data["uf"] == "MT"
municipios_mt = data.loc[mask]
municipios_mt

# Exportando arquivo
path_out = os.getcwd() + "/dados/derivados/municipios_mt.shp"
municipios_mt.to_file(path_out)

# %% [markdown]
# 5) Abra esse novo arquivo e calcule as áreas de cada município

# %%
# Importando novos arquivos
data_mt = gpd.read_file(path_out)
data_mt

# Calcular áreas dos municípios
data_mt["area"] = data_mt.loc[:,'geometry'].area
data_mt
# Out:
# C:\Users\Marcelo\AppData\Local\Temp\ipykernel_22916\1038092084.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   data_mt["area"] = data_mt.loc[:,'geometry'].area
#        id  id_pk geocodigo                municipio  uf        regiao  \
# 0       1      1   5100102                 Acorizal  MT  Centro-Oeste
# 1       2    104   5107156       Reserva Do Cabaçal  MT  Centro-Oeste
# 2    1844     50   5104203               Guiratinga  MT  Centro-Oeste
# 3    1905    100   5107008                  Poxoréo  MT  Centro-Oeste
# 4    1849     84   5106273  Novo Horizonte Do Norte  MT  Centro-Oeste
# ..    ...    ...       ...                      ...  ..           ...
# 137  2163    126   5107909                    Sinop  MT  Centro-Oeste
# 138  2164    127   5107925                  Sorriso  MT  Centro-Oeste
# ...

# %% [markdown]
# 7) Crie um novo campo para  classificação dos municípios com relação às áreas

# %% [markdown]
# 8) Selecione áreas maiores que XXX e classifique como 1 e o restante como zero

# %%
mask2 = data_mt["area"]>0.10
data_mt.loc[mask2]
# Out:
#        id  id_pk geocodigo           municipio  uf        regiao      area  \
# 1       2    104   5107156  Reserva Do Cabaçal  MT  Centro-Oeste  0.112314
# 2    1844     50   5104203          Guiratinga  MT  Centro-Oeste  0.428165
# 3    1905    100   5107008             Poxoréo  MT  Centro-Oeste  0.582975
# 5    1850     85   5106281    Novo São Joaquim  MT  Centro-Oeste  0.423267
# 6    1851     86   5106299           Paranaíta  MT  Centro-Oeste  0.395032
# ..    ...    ...       ...                 ...  ..           ...       ...
# 136  2162    125   5107883  Serra Nova Dourada  MT  Centro-Oeste  0.124555
# 137  2163    126   5107909               Sinop  MT  Centro-Oeste  0.326899
# 138  2164    127   5107925             Sorriso  MT  Centro-Oeste  0.776605
# 139  2165    128   5107941            Tabaporã  MT  Centro-Oeste  0.688512
# 141  2167    140   5108857     Nova Marilândia  MT  Centro-Oeste  0.162488
#
#                                               geometry
# ...
