# %% [markdown]
# # Geopandas
# É uma ferramenta crucial para o geoprocessamento, sendo esta baseada no Pandas, que é uma biblioteca bastante utilizada em data science. O foco da biblioteca Geopandas é a análise espacial. Para mais informações acesse www.geopandas.org.

# %%
# Importando bibliotecas
import geopandas as gpd;
import matplotlib as plt;
import os;

# %% [markdown]
# Os dados geográficos mais utilizados são geopackage, shapefile, etc. É preciso fazer um download dos dados e transferir e descompactar para a pasta do projeto

# %%
# Importando e plotando shapefile
path = os.getcwd() + "/dados/municipios.shp"
data = gpd.read_file(path)
data.plot()
# Out:
# <Axes: >

# %%
print(type(data))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
data.head()
# Out:
#    id  id_pk geocodigo           municipio  uf        regiao  area  \
# 0   1      1   5100102            Acorizal  MT  Centro-Oeste   NaN
# 1   2    104   5107156  Reserva Do Cabaçal  MT  Centro-Oeste   NaN
# 2   3    144   5200100           Abadiânia  GO  Centro-Oeste   NaN
# 3   4    147   5200175  Água Fria De Goiás  GO  Centro-Oeste   NaN
# 4   5    160   5201306             Anicuns  GO  Centro-Oeste   NaN
#
#                                             geometry
# 0  POLYGON ((-56.28986 -15.23886, -56.28991 -15.2...
# 1  POLYGON ((-58.50758 -15.005, -58.72273 -15.004...
# 2  POLYGON ((-48.91412 -16.08702, -48.91283 -16.0...
# 3  POLYGON ((-47.8574 -14.76522, -47.85657 -14.76...
# 4  POLYGON ((-49.98332 -16.3266, -49.98259 -16.32...

# %% [markdown]
# O sistema de referência é uma forma de projetar um dado geográfico no planeta Terra. O arquivo .prj especifica o sistema de referência e as unidades de medida desse shapefile e para isso use a função crs

# %%
data.crs
# Out:
# <Geographic 2D CRS: EPSG:4674>
# Name: SIRGAS 2000
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Latin America - Central America and South America - onshore and offshore. Brazil - onshore and offshore.
# - bounds: (-122.19, -59.87, -25.28, 32.72)
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
data[:10] # 10 primeira linhas
# Out:
#    id  id_pk geocodigo               municipio  uf        regiao  area  \
# 0   1      1   5100102                Acorizal  MT  Centro-Oeste   NaN
# 1   2    104   5107156      Reserva Do Cabaçal  MT  Centro-Oeste   NaN
# 2   3    144   5200100               Abadiânia  GO  Centro-Oeste   NaN
# 3   4    147   5200175      Água Fria De Goiás  GO  Centro-Oeste   NaN
# 4   5    160   5201306                 Anicuns  GO  Centro-Oeste   NaN
# 5   6    157   5200902            Amorinópolis  GO  Centro-Oeste   NaN
# 6   7    357   5219803            São Domingos  GO  Centro-Oeste   NaN
# 7   8    358   5219902  São Francisco De Goiás  GO  Centro-Oeste   NaN
# 8   9    163   5201504                   Aporé  GO  Centro-Oeste   NaN
# 9  10    172   5203104                  Baliza  GO  Centro-Oeste   NaN
#
#                                             geometry
# 0  POLYGON ((-56.28986 -15.23886, -56.28991 -15.2...
# 1  POLYGON ((-58.50758 -15.005, -58.72273 -15.004...
# 2  POLYGON ((-48.91412 -16.08702, -48.91283 -16.0...
# 3  POLYGON ((-47.8574 -14.76522, -47.85657 -14.76...
# 4  POLYGON ((-49.98332 -16.3266, -49.98259 -16.32...
# 5  POLYGON ((-51.221 -16.5038, -51.22055 -16.5036...
# 6  POLYGON ((-46.77427 -13.53235, -46.77375 -13.5...
# 7  POLYGON ((-49.33483 -15.85131, -49.33292 -15.8...
# 8  POLYGON ((-52.10182 -18.51792, -52.10103 -18.5...
# 9  POLYGON ((-52.54965 -16.19449, -52.55019 -16.1...

# %% [markdown]
# ## loc e ilock
# Serve para fazer seleção e filtragem de camadas.
# O loc usa sempre linhas, colunas e os índices. <br/>
# Um dos diferenciais é que ele utiliza booleanos e desta forma é possível criar regras

# %% [markdown]
# ### loc

# %%
data.loc[:10,:'municipio']
# Out:
#     id  id_pk geocodigo               municipio
# 0    1      1   5100102                Acorizal
# 1    2    104   5107156      Reserva Do Cabaçal
# 2    3    144   5200100               Abadiânia
# 3    4    147   5200175      Água Fria De Goiás
# 4    5    160   5201306                 Anicuns
# 5    6    157   5200902            Amorinópolis
# 6    7    357   5219803            São Domingos
# 7    8    358   5219902  São Francisco De Goiás
# 8    9    163   5201504                   Aporé
# 9   10    172   5203104                  Baliza
# 10  11    178   5203575               Bonópolis

# %%
filtro_bol = data['id']>4000
datafilter = data.loc[filtro_bol] # os dados são selecionados de acordo com um filtro booleano
datafilter.plot()
# Out:
# <Axes: >

# %%
uf_ma = data['uf']=='MA'
maranhao1 = data.loc[uf_ma]
maranhao1.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### iloc
# É exatamente a mesma coisa do loc, com o diferencial que o iloc trabalha somente com valores numéricos

# %%
data.iloc[:5,3:5]
# Out:
#             municipio  uf
# 0            Acorizal  MT
# 1  Reserva Do Cabaçal  MT
# 2           Abadiânia  GO
# 3  Água Fria De Goiás  GO
# 4             Anicuns  GO
